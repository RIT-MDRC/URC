# %%
import ikpy.chain
import numpy as np
import ikpy.utils.plot as plot_utils

# %%
my_chain = ikpy.chain.Chain.from_urdf_file("C:/Users/Kirin/OneDrive/Desktop/URC/Kinematic Model/urdf/Kinematic Model.urdf")
my_chain.forward_kinematics([0] * 7)[:3, 3]
# Out:
# array([ 5.59999822e-01, -4.45942958e-04,  4.00000000e-01])

# %%
target_position = [ 0.4, 0.3, 0.3]
print("The angles of each joints are : ", my_chain.inverse_kinematics(target_position))
# Out:
# The angles of each joints are :  [ 0.00000000e+00  6.53204178e-01  3.71396069e-03 -7.73542008e-11
#   1.10583004e+00 -8.91845760e-02  0.00000000e+00]

# %%
real_frame = my_chain.forward_kinematics(my_chain.inverse_kinematics(target_position))
print("Computed position vector : %s, original position vector : %s" % (real_frame[:3, 3], target_position))
# Out:
# Computed position vector : [0.40000013 0.30000009 0.30000006], original position vector : [0.4, 0.3, 0.3]

# %%
# %matplotlib inline
# %matplotlib widget
import matplotlib.pyplot as plt
fig, ax = plot_utils.init_3d_figure()
my_chain.plot(my_chain.inverse_kinematics(target_position), ax, target=target_position)
plt.xlim(-0.5, 0.5)
plt.ylim(-0.5, 0.5)
# Out:
# (-0.5, 0.5)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
